# %% [raw]
# {
#  "cells": [
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "# MLOps Assignment 2 - Group 70\n",
#     "## Cats vs Dogs Classification Pipeline\n",
#     "\n",
#     "This notebook demonstrates the end-to-end MLOps pipeline for binary image classification."
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "## M1: Model Development & Experiment Tracking\n",
#     "\n",
#     "### 1.1 Data & Code Versioning\n",
#     "- Git for source code versioning\n",
#     "- DVC for dataset versioning"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "# Check Git status\n",
#     "!git status"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "# Check DVC status\n",
#     "!dvc status"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "### 1.2 Data Preparation"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "# Prepare sample dataset\n",
#     "!python scripts/prepare_data.py --sample --source data/raw --output data/processed"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "# Check dataset structure\n",
#     "import os\n",
#     "for split in ['train', 'val', 'test']:\n",
#     "    for cls in ['cats', 'dogs']:\n",
#     "        path = f'data/processed/{split}/{cls}'\n",
#     "        if os.path.exists(path):\n",
#     "            count = len(os.listdir(path))\n",
#     "            print(f'{split}/{cls}: {count} images')"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "### 1.3 Model Building"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "from src.model import create_baseline_cnn, create_simple_cnn\n",
#     "\n",
#     "# Create model\n",
#     "model = create_baseline_cnn()\n",
#     "model.summary()"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "### 1.4 Training with MLflow Tracking"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "# Train model (small example)\n",
#     "!python src/train.py --data-dir data/processed/train --epochs 5 --model-type simple"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "## M2: Model Packaging & Containerization\n",
#     "\n",
#     "### 2.1 API Endpoints"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "# Show API endpoints\n",
#     "print(\"Available API Endpoints:\")\n",
#     "print(\"- GET  /           - API information\")\n",
#     "print(\"- GET  /health     - Health check\")\n",
#     "print(\"- GET  /model/info - Model information\")\n",
#     "print(\"- POST /predict    - Make prediction (file upload)\")\n",
#     "print(\"- POST /predict/base64 - Make prediction (base64)\")\n",
#     "print(\"- GET  /metrics    - Prometheus metrics\")\n",
#     "print(\"- GET  /stats      - Service statistics\")"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "### 2.2 Docker Build"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "# Build Docker image\n",
#     "!docker build -t cats-dogs-classifier:latest ."
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "## M3: CI Pipeline\n",
#     "\n",
#     "### 3.1 Running Tests"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "# Run unit tests\n",
#     "!pytest tests/ -v"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "## M4: CD Pipeline & Deployment\n",
#     "\n",
#     "### 4.1 Deploy with Docker Compose"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "# Start services\n",
#     "!docker-compose up -d"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "# Run smoke tests\n",
#     "!./scripts/smoke_test.sh"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "## M5: Monitoring & Logging\n",
#     "\n",
#     "### 5.1 Performance Tracking"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "# Simulate and track predictions\n",
#     "!python scripts/track_performance.py --samples 50"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "## Summary\n",
#     "\n",
#     "This MLOps pipeline includes:\n",
#     "\n",
#     "| Milestone | Components |\n",
#     "|-----------|------------|\n",
#     "| M1 | Git, DVC, CNN Model, MLflow |\n",
#     "| M2 | FastAPI, requirements.txt, Dockerfile |\n",
#     "| M3 | pytest, GitHub Actions CI |\n",
#     "| M4 | Kubernetes, Docker Compose, Smoke Tests |\n",
#     "| M5 | Prometheus, Grafana, Performance Tracking |"
#    ]
#   }
#  ],
#  "metadata": {
#   "kernelspec": {
#    "display_name": "Python 3",
#    "language": "python",
#    "name": "python3"
#   },
#   "language_info": {
#    "name": "python",
#    "version": "3.10.0"
#   }
#  },
#  "nbformat": 4,
#  "nbformat_minor": 4
# }
